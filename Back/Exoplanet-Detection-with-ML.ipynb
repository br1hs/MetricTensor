# %%
# !pip install uv
# !uv pip install 'autogluon.tabular[mitra]'
# Out:
# Requirement already satisfied: uv in /home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages (0.8.22)
# Using Python 3.11.2 environment at: /home/jsr-mario/.venvs/jupyter_env
# Audited 1 package in 36ms

# %%
# !uv pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121

# %%
import pandas as pd
import numpy as np
from autogluon.tabular import TabularDataset, TabularPredictor
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_wine
import torch
from sklearn.metrics import (
    accuracy_score, classification_report,
    confusion_matrix, average_precision_score,
    precision_recall_curve, roc_auc_score
)
import matplotlib.pyplot as plt

# %%
data = '../Data/1_cumulative_2025.csv'
df = pd.read_csv(data)

print(df.shape)
# Out:
# (9564, 83)

# %%
df['target'] = (df['koi_disposition'] == 'CONFIRMED').astype(int)
df = df.dropna(subset=['target'])

# %%
print(df.shape)
print("Features disponibles:", df.columns.tolist())
# Out:
# (9564, 84)
# Features disponibles: ['rowid', 'kepid', 'kepoi_name', 'kepler_name', 'koi_disposition', 'koi_vet_stat', 'koi_vet_date', 'koi_pdisposition', 'koi_score', 'koi_fpflag_nt', 'koi_fpflag_ss', 'koi_fpflag_co', 'koi_fpflag_ec', 'koi_disp_prov', 'koi_comment', 'koi_period', 'koi_time0bk', 'koi_time0', 'koi_eccen', 'koi_longp', 'koi_impact', 'koi_duration', 'koi_ingress', 'koi_depth', 'koi_ror', 'koi_srho', 'koi_fittype', 'koi_prad', 'koi_sma', 'koi_incl', 'koi_teq', 'koi_insol', 'koi_dor', 'koi_limbdark_mod', 'koi_ldm_coeff4', 'koi_ldm_coeff3', 'koi_ldm_coeff2', 'koi_ldm_coeff1', 'koi_parm_prov', 'koi_max_sngle_ev', 'koi_max_mult_ev', 'koi_model_snr', 'koi_count', 'koi_num_transits', 'koi_tce_plnt_num', 'koi_tce_delivname', 'koi_quarters', 'koi_bin_oedp_sig', 'koi_trans_mod', 'koi_model_dof', 'koi_model_chisq', 'koi_datalink_dvr', 'koi_datalink_dvs', 'koi_steff', 'koi_slogg', 'koi_smet', 'koi_srad', 'koi_smass', 'koi_sage', 'koi_sparprov', 'ra', 'dec', 'koi_kepmag', 'koi_gmag', 'koi_rmag', 'koi_imag', 'koi_zmag', 'koi_jmag', 'koi_hmag', 'koi_kmag', 'koi_fwm_stat_sig', 'koi_fwm_sra', 'koi_fwm_sdec', 'koi_fwm_srao', 'koi_fwm_sdeco', 'koi_fwm_prao', 'koi_fwm_pdeco', 'koi_dicco_mra', 'koi_dicco_mdec', 'koi_dicco_msky', 'koi_dikco_mra', 'koi_dikco_mdec', 'koi_dikco_msky', 'target']

# %%
drop_cols = [
    # 100% NaN
    'koi_longp', 'koi_model_chisq', 'koi_model_dof', 'koi_ingress', 'koi_sage',
    
    # IDs / nombres únicos / paths (no útiles como features)
    'rowid', 'kepoi_name', 
    
    # nombre oficial -> leakage (presente mayormente para confirmed)
    'kepler_name',
    
    # vetado / metadatos constantes o que filtran la etiqueta
    'koi_vet_stat', 'koi_vet_date', 'koi_disp_prov', 'koi_parm_prov',
    
    # delivery / report paths (cada fila distinto)
    'koi_tce_delivname', 'koi_datalink_dvr', 'koi_datalink_dvs',
    
    # columnas constantes según tu inspección (no aportan)
    'koi_limbdark_mod', 'koi_trans_mod', 'koi_ldm_coeff3', 'koi_ldm_coeff4',
    
    # CRÍTICO: Agregar estas
    'koi_disposition',      # target original
    'koi_pdisposition',     # disposición planetaria (LEAKAGE!)
    'koi_score',           # score de clasificación (posible LEAKAGE)
    'koi_comment',         # comentarios (posible LEAKAGE)

    # FLAGS DE VETTING (posible leakage indirecto)
    'koi_fpflag_nt',   # Flag: not transit-like
    'koi_fpflag_ss',   # Flag: stellar eclipse
    'koi_fpflag_co',   # Flag: centroid offset
    'koi_fpflag_ec',   # Flag: ephemeris match
    
    # MÉTRICAS DERIVADAS DEL VETTING
    'koi_max_mult_ev', # Eventos múltiples (calculado post-análisis)
    'koi_dicco_msky',  # Diferencia en centroide
    'koi_dikco_msky',  # Similar a dicco
    
    # OTROS SOSPECHOSOS
    'koi_bin_oedp_sig', # Significancia de odd-even depth (post-análisis)
]

drop_exist = [c for c in drop_cols]
df = df.drop(columns=drop_exist)

# %%
print(df.shape)
print("Features disponibles:", df.columns.tolist())
# Out:
# (9564, 53)
# Features disponibles: ['kepid', 'koi_period', 'koi_time0bk', 'koi_time0', 'koi_eccen', 'koi_impact', 'koi_duration', 'koi_depth', 'koi_ror', 'koi_srho', 'koi_fittype', 'koi_prad', 'koi_sma', 'koi_incl', 'koi_teq', 'koi_insol', 'koi_dor', 'koi_ldm_coeff2', 'koi_ldm_coeff1', 'koi_max_sngle_ev', 'koi_model_snr', 'koi_count', 'koi_num_transits', 'koi_tce_plnt_num', 'koi_quarters', 'koi_steff', 'koi_slogg', 'koi_smet', 'koi_srad', 'koi_smass', 'koi_sparprov', 'ra', 'dec', 'koi_kepmag', 'koi_gmag', 'koi_rmag', 'koi_imag', 'koi_zmag', 'koi_jmag', 'koi_hmag', 'koi_kmag', 'koi_fwm_stat_sig', 'koi_fwm_sra', 'koi_fwm_sdec', 'koi_fwm_srao', 'koi_fwm_sdeco', 'koi_fwm_prao', 'koi_fwm_pdeco', 'koi_dicco_mra', 'koi_dicco_mdec', 'koi_dikco_mra', 'koi_dikco_mdec', 'target']

# %%
# 2. Densidad estelar vs período (ley de Kepler)
df['kepler_ratio'] = df['koi_srho'] * (df['koi_period'] ** 2)

# 3. Temperatura de equilibrio vs temperatura estelar
df['temp_ratio'] = df['koi_teq'] / df['koi_steff']

# 4. Duración esperada vs observada
expected_duration = 13 * df['koi_srad'] * (df['koi_period'] / 365.25) ** (1/3)
df['duration_anomaly'] = (df['koi_duration'] - expected_duration).abs()

# 5. Marca tránsitos ultra-profundos
df['ultra_deep'] = (df['koi_depth'] > 5000).astype(int)

df['log_period'] = np.log10(df['koi_period'])
df['log_depth'] = np.log10(df['koi_depth'])
df['log_prad'] = np.log10(df['koi_prad'])
df['log_teq'] = np.log10(df['koi_teq'])

# Clasificar por tipo de órbita
def classify_period(p):
    if p < 1:
        return 'ultra_short'  # Júpiter caliente extremo
    elif p < 10:
        return 'short'        # Júpiter caliente
    elif p < 100:
        return 'medium'       # Similar a Venus/Mercurio
    else:
        return 'long'         # Similar a Tierra o más

df['period_class'] = df['koi_period'].apply(classify_period)
# Out:
# /home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
print(df.shape)
print("Features disponibles:", df.columns.tolist())
# Out:
# (9564, 62)
# Features disponibles: ['kepid', 'koi_period', 'koi_time0bk', 'koi_time0', 'koi_eccen', 'koi_impact', 'koi_duration', 'koi_depth', 'koi_ror', 'koi_srho', 'koi_fittype', 'koi_prad', 'koi_sma', 'koi_incl', 'koi_teq', 'koi_insol', 'koi_dor', 'koi_ldm_coeff2', 'koi_ldm_coeff1', 'koi_max_sngle_ev', 'koi_model_snr', 'koi_count', 'koi_num_transits', 'koi_tce_plnt_num', 'koi_quarters', 'koi_steff', 'koi_slogg', 'koi_smet', 'koi_srad', 'koi_smass', 'koi_sparprov', 'ra', 'dec', 'koi_kepmag', 'koi_gmag', 'koi_rmag', 'koi_imag', 'koi_zmag', 'koi_jmag', 'koi_hmag', 'koi_kmag', 'koi_fwm_stat_sig', 'koi_fwm_sra', 'koi_fwm_sdec', 'koi_fwm_srao', 'koi_fwm_sdeco', 'koi_fwm_prao', 'koi_fwm_pdeco', 'koi_dicco_mra', 'koi_dicco_mdec', 'koi_dikco_mra', 'koi_dikco_mdec', 'target', 'kepler_ratio', 'temp_ratio', 'duration_anomaly', 'ultra_deep', 'log_period', 'log_depth', 'log_prad', 'log_teq', 'period_class']

# %%
#  agregar features derivadas

# Duración relativa del tránsito
df['transit_ratio'] = df['koi_duration'] / (df['koi_period'] * 24)  # en horas

# Temperatura vs período (ley de Kepler simplificada)
df['temp_period_ratio'] = df['koi_steff'] / np.sqrt(df['koi_period'])

# Impacto del tránsito (centralidad)
df['impact_squared'] = df['koi_impact'] ** 2

print(f"Shape con features nuevas: {df.shape}")
# Out:
# Shape con features nuevas: (9564, 65)

# %%
# df2 = pd.DataFrame()

# import math

df['transit_morgan'] = ( (df['koi_period'].astype(float) * df['koi_srad'].astype(float))
                          / (np.pi * df['koi_sma'].astype(float)) ) \
                        * np.sqrt(((1 + df['koi_prad'].astype(float) / df['koi_srad'].astype(float))**2)
                                  - df['koi_impact'].astype(float)**2)

df['caida_brillo']= (df['koi_ror'])**2


# Clasificar por número de tránsitos
def classify_transits(n):
    if n >= 3:
        return 1   # Candidato a planeta
    elif 1 <= n <= 2:
        return -1     # Falso positivo

# df['transit_class'] = df['koi_num_transits'].apply(classify_transits)
# cols = [
#     'target',
#     "koi_period",
#     "koi_duration",
#     # "koi_ingress",
#     "koi_depth",
#     "koi_ror",
#     "koi_srho",
#     "koi_fittype",
#     "koi_prad",
#     "koi_insol",
#     "koi_srad",
#     "koi_impact",
#     "koi_sma"
# ]


# for c in cols:
#     df2[c] = df[c]

# df = df2
# print(df.shape)

# %%
train, test = train_test_split(df, test_size=0.3, random_state=42, stratify=df['target'])
train_data = TabularDataset(train)
test_data = TabularDataset(test)

# %%
full_predictor = TabularPredictor(label='target', eval_metric='roc_auc', verbosity=1)

hyperparameters = {
    'GBM': {},
    'CAT': {},
    'XGB': {},
}

full_predictor.fit(
    train_data,
    presets='best_quality',
    time_limit=400,
    hyperparameters=hyperparameters,
    hyperparameter_tune_kwargs={
      'num_trials': 4,
      'scheduler': 'local',
      'searcher': 'random',
    },
    num_bag_folds=2,
    num_stack_levels=2,  # Limitar stacking
)


print("\nModel Leaderboard:")
full_predictor.leaderboard(test_data)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20251005_205401"
# Warning: hyperparameter tuning is currently experimental and may cause the process to hang.
# 2025-10-05 14:54:03,029	INFO worker.py:1843 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
#   0%|          | 0/4 [00:00<?, ?it/s]
#  25%|██▌       | 1/4 [00:02<00:06,  2.04s/it]
#  50%|█████     | 2/4 [00:04<00:04,  2.22s/it]
#  75%|███████▌  | 3/4 [00:06<00:02,  2.24s/it]
#  75%|███████▌  | 3/4 [00:11<00:03,  3.82s/it]
#   0%|          | 0/4 [00:00<?, ?it/s]
#  25%|██▌       | 1/4 [00:04<00:14,  4.75s/it]
#  50%|█████     | 2/4 [00:08<00:07,  3.90s/it]
#  50%|█████     | 2/4 [00:12<00:12,  6.02s/it]
#   0%|          | 0/4 [00:00<?, ?it/s]
# (_dystack pid=12634) ray::_ray_fit() (pid=14366, ip=10.150.159.135)
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 446, in _ray_fit
# (_dystack pid=12634)     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1068, in fit
# (_dystack pid=12634)     out = self._fit(**kwargs)
# (_dystack pid=12634)           ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/tabular/models/xgboost/xgboost_model.py", line 191, in _fit
# (_dystack pid=12634)     self.model.fit(X=X, y=y, eval_set=eval_set, verbose=False, sample_weight=sample_weight)
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/core.py", line 729, in inner_f
# (_dystack pid=12634)     return func(**kwargs)
# (_dystack pid=12634)            ^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/sklearn.py", line 1664, in fit
# (_dystack pid=12634)     train_dmatrix, evals = _wrap_evaluation_matrices(
# (_dystack pid=12634)                            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/sklearn.py", line 679, in _wrap_evaluation_matrices
# (_dystack pid=12634)     m = create_dmatrix(
# (_dystack pid=12634)         ^^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/sklearn.py", line 1137, in _create_dmatrix
# (_dystack pid=12634)     return QuantileDMatrix(
# (_dystack pid=12634)            ^^^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/core.py", line 729, in inner_f
# (_dystack pid=12634)     return func(**kwargs)
# (_dystack pid=12634)            ^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/core.py", line 1614, in __init__
# (_dystack pid=12634)     self._init(
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/core.py", line 1680, in _init
# (_dystack pid=12634)     _check_call(ret)
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/core.py", line 310, in _check_call
# (_dystack pid=12634)     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# (_dystack pid=12634) xgboost.core.XGBoostError: [14:54:30] /workspace/src/data/gradient_index.h:100: Check failed: valid: Input data contains `inf` or a value too large, while `missing` is not set to `inf`
# (_dystack pid=12634) Stack trace:
# (_dystack pid=12634)   [bt] (0) /home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/lib/libxgboost.so(+0x2a6e7c) [0x7f604cea6e7c]
# (_dystack pid=12634)   [bt] (1) /home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/lib/libxgboost.so(+0x5e9e74) [0x7f604d1e9e74]
# (_dystack pid=12634)   [bt] (2) /home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/lib/libxgboost.so(+0x5ea8f9) [0x7f604d1ea8f9]
# (_dystack pid=12634)   [bt] (3) /home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/lib/libxgboost.so(+0x57b4f1) [0x7f604d17b4f1]
# (_dystack pid=12634)   [bt] (4) /home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/lib/libxgboost.so(XGQuantileDMatrixCreateFromCallback+0x178) [0x7f604cdb9378]
# (_dystack pid=12634)   [bt] (5) /lib/x86_64-linux-gnu/libffi.so.8(+0x6f7a) [0x7f617e0faf7a]
# (_dystack pid=12634)   [bt] (6) /lib/x86_64-linux-gnu/libffi.so.8(+0x640e) [0x7f617e0fa40e]
# (_dystack pid=12634)   [bt] (7) /lib/x86_64-linux-gnu/libffi.so.8(ffi_call+0xcd) [0x7f617e0fab0d]
# (_dystack pid=12634)   [bt] (8) /usr/lib/python3.11/lib-dynload/_ctypes.cpython-311-x86_64-linux-gnu.so(+0xa42b) [0x7f617e70f42b]
# (_dystack pid=12634) Traceback (most recent call last):
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/core/models/abstract/model_trial.py", line 37, in model_trial
# (_dystack pid=12634)     model = fit_and_save_model(
# (_dystack pid=12634)             ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/core/models/abstract/model_trial.py", line 96, in fit_and_save_model
# (_dystack pid=12634)     model.fit(**fit_args, time_limit=time_left)
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1068, in fit
# (_dystack pid=12634)     out = self._fit(**kwargs)
# (_dystack pid=12634)           ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/core/models/ensemble/stacker_ensemble_model.py", line 270, in _fit
# (_dystack pid=12634)     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
# (_dystack pid=12634)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 389, in _fit
# (_dystack pid=12634)     self._fit_folds(
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 868, in _fit_folds
# (_dystack pid=12634)     fold_fitting_strategy.after_all_folds_scheduled()
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 723, in after_all_folds_scheduled
# (_dystack pid=12634)     self._run_parallel(X, y, X_pseudo, y_pseudo, model_base_ref, time_limit_fold, head_node_id)
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 664, in _run_parallel
# (_dystack pid=12634)     self._process_fold_results(finished, unfinished, fold_ctx)
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 620, in _process_fold_results
# (_dystack pid=12634)     raise processed_exception
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 583, in _process_fold_results
# (_dystack pid=12634)     fold_model, pred_proba, time_start_fit, time_end_fit, predict_time, predict_1_time, predict_n_size, fit_num_cpus, fit_num_gpus = self.ray.get(finished)
# (_dystack pid=12634)                                                                                                                                      ^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
# (_dystack pid=12634)     return fn(*args, **kwargs)
# (_dystack pid=12634)            ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
# (_dystack pid=12634)     return func(*args, **kwargs)
# (_dystack pid=12634)            ^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/ray/_private/worker.py", line 2782, in get
# (_dystack pid=12634)     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
# (_dystack pid=12634)                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/ray/_private/worker.py", line 929, in get_objects
# (_dystack pid=12634)     raise value.as_instanceof_cause()
# (_dystack pid=12634) ray.exceptions.RayTaskError(XGBoostError): ray::_ray_fit() (pid=14366, ip=10.150.159.135)
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 446, in _ray_fit
# (_dystack pid=12634)     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1068, in fit
# (_dystack pid=12634)     out = self._fit(**kwargs)
# (_dystack pid=12634)           ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/tabular/models/xgboost/xgboost_model.py", line 191, in _fit
# (_dystack pid=12634)     self.model.fit(X=X, y=y, eval_set=eval_set, verbose=False, sample_weight=sample_weight)
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/core.py", line 729, in inner_f
# (_dystack pid=12634)     return func(**kwargs)
# (_dystack pid=12634)            ^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/sklearn.py", line 1664, in fit
# (_dystack pid=12634)     train_dmatrix, evals = _wrap_evaluation_matrices(
# (_dystack pid=12634)                            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/sklearn.py", line 679, in _wrap_evaluation_matrices
# (_dystack pid=12634)     m = create_dmatrix(
# (_dystack pid=12634)         ^^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/sklearn.py", line 1137, in _create_dmatrix
# (_dystack pid=12634)     return QuantileDMatrix(
# (_dystack pid=12634)            ^^^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/core.py", line 729, in inner_f
# (_dystack pid=12634)     return func(**kwargs)
# (_dystack pid=12634)            ^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/core.py", line 1614, in __init__
# (_dystack pid=12634)     self._init(
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/core.py", line 1680, in _init
# (_dystack pid=12634)     _check_call(ret)
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/core.py", line 310, in _check_call
# (_dystack pid=12634)     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# (_dystack pid=12634) xgboost.core.XGBoostError: [14:54:30] /workspace/src/data/gradient_index.h:100: Check failed: valid: Input data contains `inf` or a value too large, while `missing` is not set to `inf`
# (_dystack pid=12634) Stack trace:
# (_dystack pid=12634)   [bt] (0) /home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/lib/libxgboost.so(+0x2a6e7c) [0x7f604cea6e7c]
# (_dystack pid=12634)   [bt] (1) /home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/lib/libxgboost.so(+0x5e9e74) [0x7f604d1e9e74]
# (_dystack pid=12634)   [bt] (2) /home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/lib/libxgboost.so(+0x5ea8f9) [0x7f604d1ea8f9]
# (_dystack pid=12634)   [bt] (3) /home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/lib/libxgboost.so(+0x57b4f1) [0x7f604d17b4f1]
# (_dystack pid=12634)   [bt] (4) /home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/lib/libxgboost.so(XGQuantileDMatrixCreateFromCallback+0x178) [0x7f604cdb9378]
# (_dystack pid=12634)   [bt] (5) /lib/x86_64-linux-gnu/libffi.so.8(+0x6f7a) [0x7f617e0faf7a]
# (_dystack pid=12634)   [bt] (6) /lib/x86_64-linux-gnu/libffi.so.8(+0x640e) [0x7f617e0fa40e]
# (_dystack pid=12634)   [bt] (7) /lib/x86_64-linux-gnu/libffi.so.8(ffi_call+0xcd) [0x7f617e0fab0d]
# (_dystack pid=12634)   [bt] (8) /usr/lib/python3.11/lib-dynload/_ctypes.cpython-311-x86_64-linux-gnu.so(+0xa42b) [0x7f617e70f42b]
#  25%|██▌       | 1/4 [00:01<00:03,  1.13s/it]Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=14367, ip=10.150.159.135)
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 446, in _ray_fit
# (_dystack pid=12634)     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1068, in fit
# (_dystack pid=12634)     out = self._fit(**kwargs)
# (_dystack pid=12634)           ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/tabular/models/xgboost/xgboost_model.py", line 191, in _fit
# (_dystack pid=12634)     self.model.fit(X=X, y=y, eval_set=eval_set, verbose=False, sample_weight=sample_weight)
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/core.py", line 729, in inner_f
# (_dystack pid=12634)     return func(**kwargs)
# (_dystack pid=12634)            ^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/sklearn.py", line 1664, in fit
# (_dystack pid=12634)     train_dmatrix, evals = _wrap_evaluation_matrices(
# (_dystack pid=12634)                            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/sklearn.py", line 628, in _wrap_evaluation_matrices
# (_dystack pid=12634)     train_dmatrix = create_dmatrix(
# (_dystack pid=12634)                     ^^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/sklearn.py", line 1137, in _create_dmatrix
# (_dystack pid=12634)     return QuantileDMatrix(
# (_dystack pid=12634)            ^^^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/core.py", line 729, in inner_f
# (_dystack pid=12634)     return func(**kwargs)
# (_dystack pid=12634)            ^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/core.py", line 1614, in __init__
# (_dystack pid=12634)     self._init(
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/core.py", line 1680, in _init
# (_dystack pid=12634)     _check_call(ret)
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/core.py", line 310, in _check_call
# (_dystack pid=12634)     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# (_dystack pid=12634) xgboost.core.XGBoostError: [14:54:30] /workspace/src/data/gradient_index.h:100: Check failed: valid: Input data contains `inf` or a value too large, while `missing` is not set to `inf`
# (_dystack pid=12634) Stack trace:
# (_dystack pid=12634)   [bt] (0) /home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/lib/libxgboost.so(+0x2a6e7c) [0x7fbc7a0a6e7c]
# (_dystack pid=12634)   [bt] (1) /home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/lib/libxgboost.so(+0x5e9e74) [0x7fbc7a3e9e74]
# (_dystack pid=12634)   [bt] (2) /home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/lib/libxgboost.so(+0x5ea8f9) [0x7fbc7a3ea8f9]
# (_dystack pid=12634)   [bt] (3) /home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/lib/libxgboost.so(+0x57b4f1) [0x7fbc7a37b4f1]
# (_dystack pid=12634)   [bt] (4) /home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/lib/libxgboost.so(XGQuantileDMatrixCreateFromCallback+0x178) [0x7fbc79fb9378]
# (_dystack pid=12634)   [bt] (5) /lib/x86_64-linux-gnu/libffi.so.8(+0x6f7a) [0x7fbdab46ef7a]
# (_dystack pid=12634)   [bt] (6) /lib/x86_64-linux-gnu/libffi.so.8(+0x640e) [0x7fbdab46e40e]
# (_dystack pid=12634)   [bt] (7) /lib/x86_64-linux-gnu/libffi.so.8(ffi_call+0xcd) [0x7fbdab46eb0d]
# (_dystack pid=12634)   [bt] (8) /usr/lib/python3.11/lib-dynload/_ctypes.cpython-311-x86_64-linux-gnu.so(+0xa42b) [0x7fbdab49442b]
# (_dystack pid=12634) ray::_ray_fit() (pid=14493, ip=10.150.159.135)
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 446, in _ray_fit
# (_dystack pid=12634)     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1068, in fit
# (_dystack pid=12634)     out = self._fit(**kwargs)
# (_dystack pid=12634)           ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/tabular/models/xgboost/xgboost_model.py", line 191, in _fit
# (_dystack pid=12634)     self.model.fit(X=X, y=y, eval_set=eval_set, verbose=False, sample_weight=sample_weight)
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/core.py", line 729, in inner_f
# (_dystack pid=12634)     return func(**kwargs)
# (_dystack pid=12634)            ^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/sklearn.py", line 1664, in fit
# (_dystack pid=12634)     train_dmatrix, evals = _wrap_evaluation_matrices(
# (_dystack pid=12634)                            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/sklearn.py", line 628, in _wrap_evaluation_matrices
# (_dystack pid=12634)     train_dmatrix = create_dmatrix(
# (_dystack pid=12634)                     ^^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/sklearn.py", line 1137, in _create_dmatrix
# (_dystack pid=12634)     return QuantileDMatrix(
# (_dystack pid=12634)            ^^^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/core.py", line 729, in inner_f
# (_dystack pid=12634)     return func(**kwargs)
# (_dystack pid=12634)            ^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/core.py", line 1614, in __init__
# (_dystack pid=12634)     self._init(
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/core.py", line 1680, in _init
# (_dystack pid=12634)     _check_call(ret)
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/core.py", line 310, in _check_call
# (_dystack pid=12634)     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# (_dystack pid=12634) xgboost.core.XGBoostError: [14:54:31] /workspace/src/data/gradient_index.h:100: Check failed: valid: Input data contains `inf` or a value too large, while `missing` is not set to `inf`
# (_dystack pid=12634) Stack trace:
# (_dystack pid=12634)   [bt] (0) /home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/lib/libxgboost.so(+0x2a6e7c) [0x7f368f0a6e7c]
# (_dystack pid=12634)   [bt] (1) /home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/lib/libxgboost.so(+0x5e9e74) [0x7f368f3e9e74]
# (_dystack pid=12634)   [bt] (2) /home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/lib/libxgboost.so(+0x5ea8f9) [0x7f368f3ea8f9]
# (_dystack pid=12634)   [bt] (3) /home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/lib/libxgboost.so(+0x57b4f1) [0x7f368f37b4f1]
# (_dystack pid=12634)   [bt] (4) /home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/lib/libxgboost.so(XGQuantileDMatrixCreateFromCallback+0x178) [0x7f368efb9378]
# (_dystack pid=12634)   [bt] (5) /lib/x86_64-linux-gnu/libffi.so.8(+0x6f7a) [0x7f37c054ef7a]
# (_dystack pid=12634)   [bt] (6) /lib/x86_64-linux-gnu/libffi.so.8(+0x640e) [0x7f37c054e40e]
# (_dystack pid=12634)   [bt] (7) /lib/x86_64-linux-gnu/libffi.so.8(ffi_call+0xcd) [0x7f37c054eb0d]
# (_dystack pid=12634)   [bt] (8) /usr/lib/python3.11/lib-dynload/_ctypes.cpython-311-x86_64-linux-gnu.so(+0xa42b) [0x7f37c057442b]
# (_dystack pid=12634) Traceback (most recent call last):
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/core/models/abstract/model_trial.py", line 37, in model_trial
# (_dystack pid=12634)     model = fit_and_save_model(
# (_dystack pid=12634)             ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/core/models/abstract/model_trial.py", line 96, in fit_and_save_model
# (_dystack pid=12634)     model.fit(**fit_args, time_limit=time_left)
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1068, in fit
# (_dystack pid=12634)     out = self._fit(**kwargs)
# (_dystack pid=12634)           ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/core/models/ensemble/stacker_ensemble_model.py", line 270, in _fit
# (_dystack pid=12634)     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
# (_dystack pid=12634)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 389, in _fit
# (_dystack pid=12634)     self._fit_folds(
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 868, in _fit_folds
# (_dystack pid=12634)     fold_fitting_strategy.after_all_folds_scheduled()
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 723, in after_all_folds_scheduled
# (_dystack pid=12634)     self._run_parallel(X, y, X_pseudo, y_pseudo, model_base_ref, time_limit_fold, head_node_id)
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 664, in _run_parallel
# (_dystack pid=12634)     self._process_fold_results(finished, unfinished, fold_ctx)
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 620, in _process_fold_results
# (_dystack pid=12634)     raise processed_exception
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 583, in _process_fold_results
# (_dystack pid=12634)     fold_model, pred_proba, time_start_fit, time_end_fit, predict_time, predict_1_time, predict_n_size, fit_num_cpus, fit_num_gpus = self.ray.get(finished)
# (_dystack pid=12634)                                                                                                                                      ^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
# (_dystack pid=12634)     return fn(*args, **kwargs)
# (_dystack pid=12634)            ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
# (_dystack pid=12634)     return func(*args, **kwargs)
# (_dystack pid=12634)            ^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/ray/_private/worker.py", line 2782, in get
# (_dystack pid=12634)     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
# (_dystack pid=12634)                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/ray/_private/worker.py", line 929, in get_objects
# (_dystack pid=12634)     raise value.as_instanceof_cause()
# (_dystack pid=12634) ray.exceptions.RayTaskError(XGBoostError): ray::_ray_fit() (pid=14493, ip=10.150.159.135)
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 446, in _ray_fit
# (_dystack pid=12634)     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1068, in fit
# (_dystack pid=12634)     out = self._fit(**kwargs)
# (_dystack pid=12634)           ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/tabular/models/xgboost/xgboost_model.py", line 191, in _fit
# (_dystack pid=12634)     self.model.fit(X=X, y=y, eval_set=eval_set, verbose=False, sample_weight=sample_weight)
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/core.py", line 729, in inner_f
# (_dystack pid=12634)     return func(**kwargs)
# (_dystack pid=12634)            ^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/sklearn.py", line 1664, in fit
# (_dystack pid=12634)     train_dmatrix, evals = _wrap_evaluation_matrices(
# (_dystack pid=12634)                            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/sklearn.py", line 628, in _wrap_evaluation_matrices
# (_dystack pid=12634)     train_dmatrix = create_dmatrix(
# (_dystack pid=12634)                     ^^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/sklearn.py", line 1137, in _create_dmatrix
# (_dystack pid=12634)     return QuantileDMatrix(
# (_dystack pid=12634)            ^^^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/core.py", line 729, in inner_f
# (_dystack pid=12634)     return func(**kwargs)
# (_dystack pid=12634)            ^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/core.py", line 1614, in __init__
# (_dystack pid=12634)     self._init(
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/core.py", line 1680, in _init
# (_dystack pid=12634)     _check_call(ret)
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/core.py", line 310, in _check_call
# (_dystack pid=12634)     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# (_dystack pid=12634) xgboost.core.XGBoostError: [14:54:31] /workspace/src/data/gradient_index.h:100: Check failed: valid: Input data contains `inf` or a value too large, while `missing` is not set to `inf`
# (_dystack pid=12634) Stack trace:
# (_dystack pid=12634)   [bt] (0) /home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/lib/libxgboost.so(+0x2a6e7c) [0x7f368f0a6e7c]
# (_dystack pid=12634)   [bt] (1) /home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/lib/libxgboost.so(+0x5e9e74) [0x7f368f3e9e74]
# (_dystack pid=12634)   [bt] (2) /home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/lib/libxgboost.so(+0x5ea8f9) [0x7f368f3ea8f9]
# (_dystack pid=12634)   [bt] (3) /home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/lib/libxgboost.so(+0x57b4f1) [0x7f368f37b4f1]
# (_dystack pid=12634)   [bt] (4) /home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/lib/libxgboost.so(XGQuantileDMatrixCreateFromCallback+0x178) [0x7f368efb9378]
# (_dystack pid=12634)   [bt] (5) /lib/x86_64-linux-gnu/libffi.so.8(+0x6f7a) [0x7f37c054ef7a]
# (_dystack pid=12634)   [bt] (6) /lib/x86_64-linux-gnu/libffi.so.8(+0x640e) [0x7f37c054e40e]
# (_dystack pid=12634)   [bt] (7) /lib/x86_64-linux-gnu/libffi.so.8(ffi_call+0xcd) [0x7f37c054eb0d]
# (_dystack pid=12634)   [bt] (8) /usr/lib/python3.11/lib-dynload/_ctypes.cpython-311-x86_64-linux-gnu.so(+0xa42b) [0x7f37c057442b]
#  50%|█████     | 2/4 [00:02<00:02,  1.10s/it]Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# (_dystack pid=12634) ray::_ray_fit() (pid=14618, ip=10.150.159.135)
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 446, in _ray_fit
# (_dystack pid=12634)     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1068, in fit
# (_dystack pid=12634)     out = self._fit(**kwargs)
# (_dystack pid=12634)           ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/tabular/models/xgboost/xgboost_model.py", line 191, in _fit
# (_dystack pid=12634)     self.model.fit(X=X, y=y, eval_set=eval_set, verbose=False, sample_weight=sample_weight)
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/core.py", line 729, in inner_f
# (_dystack pid=12634)     return func(**kwargs)
# (_dystack pid=12634)            ^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/sklearn.py", line 1664, in fit
# (_dystack pid=12634)     train_dmatrix, evals = _wrap_evaluation_matrices(
# (_dystack pid=12634)                            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/sklearn.py", line 628, in _wrap_evaluation_matrices
# (_dystack pid=12634)     train_dmatrix = create_dmatrix(
# (_dystack pid=12634)                     ^^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/sklearn.py", line 1137, in _create_dmatrix
# (_dystack pid=12634)     return QuantileDMatrix(
# (_dystack pid=12634)            ^^^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/core.py", line 729, in inner_f
# (_dystack pid=12634)     return func(**kwargs)
# (_dystack pid=12634)            ^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/core.py", line 1614, in __init__
# (_dystack pid=12634)     self._init(
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/core.py", line 1680, in _init
# (_dystack pid=12634)     _check_call(ret)
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/core.py", line 310, in _check_call
# (_dystack pid=12634)     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# (_dystack pid=12634) xgboost.core.XGBoostError: [14:54:32] /workspace/src/data/gradient_index.h:100: Check failed: valid: Input data contains `inf` or a value too large, while `missing` is not set to `inf`
# (_dystack pid=12634) Stack trace:
# (_dystack pid=12634)   [bt] (0) /home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/lib/libxgboost.so(+0x2a6e7c) [0x7fd7268a6e7c]
# (_dystack pid=12634)   [bt] (1) /home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/lib/libxgboost.so(+0x5e9e74) [0x7fd726be9e74]
# (_dystack pid=12634)   [bt] (2) /home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/lib/libxgboost.so(+0x5ea8f9) [0x7fd726bea8f9]
# (_dystack pid=12634)   [bt] (3) /home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/lib/libxgboost.so(+0x57b4f1) [0x7fd726b7b4f1]
# (_dystack pid=12634)   [bt] (4) /home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/lib/libxgboost.so(XGQuantileDMatrixCreateFromCallback+0x178) [0x7fd7267b9378]
# (_dystack pid=12634)   [bt] (5) /lib/x86_64-linux-gnu/libffi.so.8(+0x6f7a) [0x7fd8584f6f7a]
# (_dystack pid=12634)   [bt] (6) /lib/x86_64-linux-gnu/libffi.so.8(+0x640e) [0x7fd8584f640e]
# (_dystack pid=12634)   [bt] (7) /lib/x86_64-linux-gnu/libffi.so.8(ffi_call+0xcd) [0x7fd8584f6b0d]
# (_dystack pid=12634)   [bt] (8) /usr/lib/python3.11/lib-dynload/_ctypes.cpython-311-x86_64-linux-gnu.so(+0xa42b) [0x7fd857eb542b]
# (_dystack pid=12634) Traceback (most recent call last):
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/core/models/abstract/model_trial.py", line 37, in model_trial
# (_dystack pid=12634)     model = fit_and_save_model(
# (_dystack pid=12634)             ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/core/models/abstract/model_trial.py", line 96, in fit_and_save_model
# (_dystack pid=12634)     model.fit(**fit_args, time_limit=time_left)
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1068, in fit
# (_dystack pid=12634)     out = self._fit(**kwargs)
# (_dystack pid=12634)           ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/core/models/ensemble/stacker_ensemble_model.py", line 270, in _fit
# (_dystack pid=12634)     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
# (_dystack pid=12634)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 389, in _fit
# (_dystack pid=12634)     self._fit_folds(
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 868, in _fit_folds
# (_dystack pid=12634)     fold_fitting_strategy.after_all_folds_scheduled()
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 723, in after_all_folds_scheduled
# (_dystack pid=12634)     self._run_parallel(X, y, X_pseudo, y_pseudo, model_base_ref, time_limit_fold, head_node_id)
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 664, in _run_parallel
# (_dystack pid=12634)     self._process_fold_results(finished, unfinished, fold_ctx)
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 620, in _process_fold_results
# (_dystack pid=12634)     raise processed_exception
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 583, in _process_fold_results
# (_dystack pid=12634)     fold_model, pred_proba, time_start_fit, time_end_fit, predict_time, predict_1_time, predict_n_size, fit_num_cpus, fit_num_gpus = self.ray.get(finished)
# (_dystack pid=12634)                                                                                                                                      ^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
# (_dystack pid=12634)     return fn(*args, **kwargs)
# (_dystack pid=12634)            ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
# (_dystack pid=12634)     return func(*args, **kwargs)
# (_dystack pid=12634)            ^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/ray/_private/worker.py", line 2782, in get
# (_dystack pid=12634)     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
# (_dystack pid=12634)                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/ray/_private/worker.py", line 929, in get_objects
# (_dystack pid=12634)     raise value.as_instanceof_cause()
# (_dystack pid=12634) ray.exceptions.RayTaskError(XGBoostError): ray::_ray_fit() (pid=14618, ip=10.150.159.135)
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 446, in _ray_fit
# (_dystack pid=12634)     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1068, in fit
# (_dystack pid=12634)     out = self._fit(**kwargs)
# (_dystack pid=12634)           ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/tabular/models/xgboost/xgboost_model.py", line 191, in _fit
# (_dystack pid=12634)     self.model.fit(X=X, y=y, eval_set=eval_set, verbose=False, sample_weight=sample_weight)
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/core.py", line 729, in inner_f
# (_dystack pid=12634)     return func(**kwargs)
# (_dystack pid=12634)            ^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/sklearn.py", line 1664, in fit
# (_dystack pid=12634)     train_dmatrix, evals = _wrap_evaluation_matrices(
# (_dystack pid=12634)                            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/sklearn.py", line 628, in _wrap_evaluation_matrices
# (_dystack pid=12634)     train_dmatrix = create_dmatrix(
# (_dystack pid=12634)                     ^^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/sklearn.py", line 1137, in _create_dmatrix
# (_dystack pid=12634)     return QuantileDMatrix(
# (_dystack pid=12634)            ^^^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/core.py", line 729, in inner_f
# (_dystack pid=12634)     return func(**kwargs)
# (_dystack pid=12634)            ^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/core.py", line 1614, in __init__
# (_dystack pid=12634)     self._init(
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/core.py", line 1680, in _init
# (_dystack pid=12634)     _check_call(ret)
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/core.py", line 310, in _check_call
# (_dystack pid=12634)     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# (_dystack pid=12634) xgboost.core.XGBoostError: [14:54:32] /workspace/src/data/gradient_index.h:100: Check failed: valid: Input data contains `inf` or a value too large, while `missing` is not set to `inf`
# (_dystack pid=12634) Stack trace:
# (_dystack pid=12634)   [bt] (0) /home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/lib/libxgboost.so(+0x2a6e7c) [0x7fd7268a6e7c]
# (_dystack pid=12634)   [bt] (1) /home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/lib/libxgboost.so(+0x5e9e74) [0x7fd726be9e74]
# (_dystack pid=12634)   [bt] (2) /home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/lib/libxgboost.so(+0x5ea8f9) [0x7fd726bea8f9]
# (_dystack pid=12634)   [bt] (3) /home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/lib/libxgboost.so(+0x57b4f1) [0x7fd726b7b4f1]
# (_dystack pid=12634)   [bt] (4) /home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/lib/libxgboost.so(XGQuantileDMatrixCreateFromCallback+0x178) [0x7fd7267b9378]
# (_dystack pid=12634)   [bt] (5) /lib/x86_64-linux-gnu/libffi.so.8(+0x6f7a) [0x7fd8584f6f7a]
# (_dystack pid=12634)   [bt] (6) /lib/x86_64-linux-gnu/libffi.so.8(+0x640e) [0x7fd8584f640e]
# (_dystack pid=12634)   [bt] (7) /lib/x86_64-linux-gnu/libffi.so.8(ffi_call+0xcd) [0x7fd8584f6b0d]
# (_dystack pid=12634)   [bt] (8) /usr/lib/python3.11/lib-dynload/_ctypes.cpython-311-x86_64-linux-gnu.so(+0xa42b) [0x7fd857eb542b]
#  75%|███████▌  | 3/4 [00:03<00:01,  1.10s/it]Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# (_dystack pid=12634) ray::_ray_fit() (pid=14739, ip=10.150.159.135)
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 446, in _ray_fit
# (_dystack pid=12634)     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1068, in fit
# (_dystack pid=12634)     out = self._fit(**kwargs)
# (_dystack pid=12634)           ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/tabular/models/xgboost/xgboost_model.py", line 191, in _fit
# (_dystack pid=12634)     self.model.fit(X=X, y=y, eval_set=eval_set, verbose=False, sample_weight=sample_weight)
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/core.py", line 729, in inner_f
# (_dystack pid=12634)     return func(**kwargs)
# (_dystack pid=12634)            ^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/sklearn.py", line 1664, in fit
# (_dystack pid=12634)     train_dmatrix, evals = _wrap_evaluation_matrices(
# (_dystack pid=12634)                            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/sklearn.py", line 628, in _wrap_evaluation_matrices
# (_dystack pid=12634)     train_dmatrix = create_dmatrix(
# (_dystack pid=12634)                     ^^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/sklearn.py", line 1137, in _create_dmatrix
# (_dystack pid=12634)     return QuantileDMatrix(
# (_dystack pid=12634)            ^^^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/core.py", line 729, in inner_f
# (_dystack pid=12634)     return func(**kwargs)
# (_dystack pid=12634)            ^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/core.py", line 1614, in __init__
# (_dystack pid=12634)     self._init(
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/core.py", line 1680, in _init
# (_dystack pid=12634)     _check_call(ret)
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/core.py", line 310, in _check_call
# (_dystack pid=12634)     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# (_dystack pid=12634) xgboost.core.XGBoostError: [14:54:33] /workspace/src/data/gradient_index.h:100: Check failed: valid: Input data contains `inf` or a value too large, while `missing` is not set to `inf`
# (_dystack pid=12634) Stack trace:
# (_dystack pid=12634)   [bt] (0) /home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/lib/libxgboost.so(+0x2a6e7c) [0x7fcbdf4a6e7c]
# (_dystack pid=12634)   [bt] (1) /home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/lib/libxgboost.so(+0x5e9e74) [0x7fcbdf7e9e74]
# (_dystack pid=12634)   [bt] (2) /home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/lib/libxgboost.so(+0x5ea8f9) [0x7fcbdf7ea8f9]
# (_dystack pid=12634)   [bt] (3) /home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/lib/libxgboost.so(+0x57b4f1) [0x7fcbdf77b4f1]
# (_dystack pid=12634)   [bt] (4) /home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/lib/libxgboost.so(XGQuantileDMatrixCreateFromCallback+0x178) [0x7fcbdf3b9378]
# (_dystack pid=12634)   [bt] (5) /lib/x86_64-linux-gnu/libffi.so.8(+0x6f7a) [0x7fcd27ef9f7a]
# (_dystack pid=12634)   [bt] (6) /lib/x86_64-linux-gnu/libffi.so.8(+0x640e) [0x7fcd27ef940e]
# (_dystack pid=12634)   [bt] (7) /lib/x86_64-linux-gnu/libffi.so.8(ffi_call+0xcd) [0x7fcd27ef9b0d]
# (_dystack pid=12634)   [bt] (8) /usr/lib/python3.11/lib-dynload/_ctypes.cpython-311-x86_64-linux-gnu.so(+0xa42b) [0x7fcd27f1f42b]
# (_dystack pid=12634) Traceback (most recent call last):
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/core/models/abstract/model_trial.py", line 37, in model_trial
# (_dystack pid=12634)     model = fit_and_save_model(
# (_dystack pid=12634)             ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/core/models/abstract/model_trial.py", line 96, in fit_and_save_model
# (_dystack pid=12634)     model.fit(**fit_args, time_limit=time_left)
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1068, in fit
# (_dystack pid=12634)     out = self._fit(**kwargs)
# (_dystack pid=12634)           ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12634)   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/core/models/ensemble/stacker_ensemble_model.py", line 270, in _fit
# (_dystack pid=12634)     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
# ...
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/tabular/models/xgboost/xgboost_model.py", line 191, in _fit
#     self.model.fit(X=X, y=y, eval_set=eval_set, verbose=False, sample_weight=sample_weight)
#   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/core.py", line 729, in inner_f
#     return func(**kwargs)
#            ^^^^^^^^^^^^^^
#   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/sklearn.py", line 1664, in fit
#     train_dmatrix, evals = _wrap_evaluation_matrices(
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/sklearn.py", line 679, in _wrap_evaluation_matrices
#     m = create_dmatrix(
#         ^^^^^^^^^^^^^^^
#   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/sklearn.py", line 1137, in _create_dmatrix
#     return QuantileDMatrix(
#            ^^^^^^^^^^^^^^^^
#   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/core.py", line 729, in inner_f
#     return func(**kwargs)
#            ^^^^^^^^^^^^^^
#   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/core.py", line 1614, in __init__
#     self._init(
#   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/core.py", line 1680, in _init
#     _check_call(ret)
#   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/core.py", line 310, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [14:57:57] /workspace/src/data/gradient_index.h:100: Check failed: valid: Input data contains `inf` or a value too large, while `missing` is not set to `inf`
# Stack trace:
#   [bt] (0) /home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/lib/libxgboost.so(+0x2a6e7c) [0x7ff9d5ea6e7c]
#   [bt] (1) /home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/lib/libxgboost.so(+0x5e9e74) [0x7ff9d61e9e74]
#   [bt] (2) /home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/lib/libxgboost.so(+0x5ea8f9) [0x7ff9d61ea8f9]
#   [bt] (3) /home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/lib/libxgboost.so(+0x57b4f1) [0x7ff9d617b4f1]
#   [bt] (4) /home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/lib/libxgboost.so(XGQuantileDMatrixCreateFromCallback+0x178) [0x7ff9d5db9378]
#   [bt] (5) /lib/x86_64-linux-gnu/libffi.so.8(+0x6f7a) [0x7ffb0728af7a]
#   [bt] (6) /lib/x86_64-linux-gnu/libffi.so.8(+0x640e) [0x7ffb0728a40e]
#   [bt] (7) /lib/x86_64-linux-gnu/libffi.so.8(ffi_call+0xcd) [0x7ffb0728ab0d]
#   [bt] (8) /usr/lib/python3.11/lib-dynload/_ctypes.cpython-311-x86_64-linux-gnu.so(+0xa42b) [0x7ffb073b542b]
# Traceback (most recent call last):
#   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/core/models/abstract/model_trial.py", line 37, in model_trial
#     model = fit_and_save_model(
#             ^^^^^^^^^^^^^^^^^^^
#   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/core/models/abstract/model_trial.py", line 96, in fit_and_save_model
#     model.fit(**fit_args, time_limit=time_left)
#   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1068, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/core/models/ensemble/stacker_ensemble_model.py", line 270, in _fit
#     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 389, in _fit
#     self._fit_folds(
#   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 868, in _fit_folds
#     fold_fitting_strategy.after_all_folds_scheduled()
#   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 723, in after_all_folds_scheduled
#     self._run_parallel(X, y, X_pseudo, y_pseudo, model_base_ref, time_limit_fold, head_node_id)
#   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 664, in _run_parallel
#     self._process_fold_results(finished, unfinished, fold_ctx)
#   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 620, in _process_fold_results
#     raise processed_exception
#   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 583, in _process_fold_results
#     fold_model, pred_proba, time_start_fit, time_end_fit, predict_time, predict_1_time, predict_n_size, fit_num_cpus, fit_num_gpus = self.ray.get(finished)
#                                                                                                                                      ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/ray/_private/worker.py", line 2782, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/ray/_private/worker.py", line 929, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(XGBoostError): ray::_ray_fit() (pid=24029, ip=10.150.159.135)
#   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 446, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1068, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/autogluon/tabular/models/xgboost/xgboost_model.py", line 191, in _fit
#     self.model.fit(X=X, y=y, eval_set=eval_set, verbose=False, sample_weight=sample_weight)
#   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/core.py", line 729, in inner_f
#     return func(**kwargs)
#            ^^^^^^^^^^^^^^
#   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/sklearn.py", line 1664, in fit
#     train_dmatrix, evals = _wrap_evaluation_matrices(
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/sklearn.py", line 679, in _wrap_evaluation_matrices
#     m = create_dmatrix(
#         ^^^^^^^^^^^^^^^
#   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/sklearn.py", line 1137, in _create_dmatrix
#     return QuantileDMatrix(
#            ^^^^^^^^^^^^^^^^
#   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/core.py", line 729, in inner_f
#     return func(**kwargs)
#            ^^^^^^^^^^^^^^
#   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/core.py", line 1614, in __init__
#     self._init(
#   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/core.py", line 1680, in _init
#     _check_call(ret)
#   File "/home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/core.py", line 310, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [14:57:57] /workspace/src/data/gradient_index.h:100: Check failed: valid: Input data contains `inf` or a value too large, while `missing` is not set to `inf`
# Stack trace:
#   [bt] (0) /home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/lib/libxgboost.so(+0x2a6e7c) [0x7ff9d5ea6e7c]
#   [bt] (1) /home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/lib/libxgboost.so(+0x5e9e74) [0x7ff9d61e9e74]
#   [bt] (2) /home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/lib/libxgboost.so(+0x5ea8f9) [0x7ff9d61ea8f9]
#   [bt] (3) /home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/lib/libxgboost.so(+0x57b4f1) [0x7ff9d617b4f1]
#   [bt] (4) /home/jsr-mario/.venvs/jupyter_env/lib/python3.11/site-packages/xgboost/lib/libxgboost.so(XGQuantileDMatrixCreateFromCallback+0x178) [0x7ff9d5db9378]
#   [bt] (5) /lib/x86_64-linux-gnu/libffi.so.8(+0x6f7a) [0x7ffb0728af7a]
#   [bt] (6) /lib/x86_64-linux-gnu/libffi.so.8(+0x640e) [0x7ffb0728a40e]
#   [bt] (7) /lib/x86_64-linux-gnu/libffi.so.8(ffi_call+0xcd) [0x7ffb0728ab0d]
#   [bt] (8) /usr/lib/python3.11/lib-dynload/_ctypes.cpython-311-x86_64-linux-gnu.so(+0xa42b) [0x7ffb073b542b]
# No model was trained during hyperparameter tuning XGBoost_BAG_L3... Skipping this model.
# 2025-10-05 14:57:58,064	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# Model Leaderboard:
#                   model  score_test  score_val eval_metric  pred_time_test  \
# 0    CatBoost_BAG_L3/T4    0.985762   0.977478     roc_auc        0.385616
# 1    CatBoost_BAG_L2/T1    0.985638   0.978001     roc_auc        0.232325
# 2    CatBoost_BAG_L2/T4    0.985545   0.978698     roc_auc        0.232583
# 3   WeightedEnsemble_L3    0.985487   0.978846     roc_auc        0.359763
# 4    CatBoost_BAG_L2/T2    0.985293   0.977617     roc_auc        0.231379
# 5   WeightedEnsemble_L2    0.985278   0.979962     roc_auc        0.211085
# 6   WeightedEnsemble_L4    0.985278   0.979962     roc_auc        0.211200
# 7    CatBoost_BAG_L2/T3    0.985226   0.978074     roc_auc        0.232830
# 8    CatBoost_BAG_L3/T1    0.985218   0.976836     roc_auc        0.384497
# 9    CatBoost_BAG_L3/T2    0.985162   0.976919     roc_auc        0.383263
# 10   CatBoost_BAG_L3/T3    0.985058   0.977489     roc_auc        0.385629
# 11   LightGBM_BAG_L3/T3    0.985058   0.975540     roc_auc        0.390981
# 12   CatBoost_BAG_L1/T1    0.984819   0.979151     roc_auc        0.035414
# 13   LightGBM_BAG_L3/T1    0.984804   0.975257     roc_auc        0.386220
# 14   CatBoost_BAG_L1/T2    0.984681   0.978172     roc_auc        0.009168
# 15   CatBoost_BAG_L1/T4    0.984595   0.978749     roc_auc        0.014569
# 16   LightGBM_BAG_L2/T3    0.984563   0.977198     roc_auc        0.241125
# 17   LightGBM_BAG_L1/T3    0.984560   0.978805     roc_auc        0.017208
# 18   LightGBM_BAG_L2/T2    0.984538   0.972648     roc_auc        0.236332
# 19   LightGBM_BAG_L1/T1    0.984497   0.978100     roc_auc        0.050792
# 20   LightGBM_BAG_L2/T1    0.984452   0.976168     roc_auc        0.259172
# 21   CatBoost_BAG_L1/T3    0.984405   0.978985     roc_auc        0.012618
# 22   LightGBM_BAG_L2/T4    0.984376   0.974939     roc_auc        0.296353
# 23   LightGBM_BAG_L1/T4    0.984118   0.977422     roc_auc        0.093087
# 24   LightGBM_BAG_L3/T4    0.984029   0.974690     roc_auc        0.441155
# 25   LightGBM_BAG_L3/T2    0.983494   0.972532     roc_auc        0.385391
# 26   LightGBM_BAG_L1/T2    0.982334   0.973316     roc_auc        0.010785
#
#     pred_time_val   fit_time  pred_time_test_marginal  pred_time_val_marginal  \
# 0        0.391373  86.428009                 0.009669                0.011789
# 1        0.216944  52.833248                 0.008636                0.014236
# 2        0.214889  53.925017                 0.008895                0.012181
# 3        0.354190  64.546451                 0.001595                0.000862
# 4        0.213787  51.385438                 0.007690                0.011079
# 5        0.190983  39.584510                 0.001966                0.000844
# 6        0.190992  39.584203                 0.002081                0.000853
# 7        0.214728  59.362159                 0.009142                0.012020
# 8        0.396509  84.555118                 0.008550                0.016925
# 9        0.389475  83.682384                 0.007316                0.009891
# 10       0.391753  91.175129                 0.009682                0.012168
# 11       0.401504  83.057267                 0.015034                0.021919
# 12       0.011567   6.576071                 0.035414                0.011567
# 13       0.392353  83.643862                 0.010273                0.012769
# 14       0.010160   4.123555                 0.009168                0.010160
# 15       0.012569   8.680067                 0.014569                0.012569
# 16       0.223462  50.799332                 0.017437                0.020754
# 17       0.023968   2.707051                 0.017208                0.023968
# 18       0.214722  50.886789                 0.012644                0.012013
# 19       0.017569   3.852532                 0.050792                0.017569
# 20       0.223701  50.394075                 0.035483                0.020993
# 21       0.011990  16.980584                 0.012618                0.011990
# 22       0.299401  53.789819                 0.072665                0.096692
# 23       0.125044   9.359899                 0.093087                0.125044
# 24       0.486049  85.793042                 0.065208                0.106465
# 25       0.391512  83.086549                 0.009444                0.011928
# 26       0.015961   3.852780                 0.010785                0.015961
#
#     fit_time_marginal  stack_level  can_infer  fit_order
# 0            6.105379            3       True         26
# 1            4.677044            2       True         14
# 2            5.768813            2       True         17
# 3            0.106820            3       True         18
# 4            3.229234            2       True         15
# 5            0.108373            2       True          9
# 6            0.108066            4       True         27
# 7           11.205955            2       True         16
# 8            4.232487            3       True         23
# 9            3.359753            3       True         24
# 10          10.852498            3       True         25
# 11           2.734636            3       True         21
# 12           6.576071            1       True          5
# 13           3.321232            3       True         19
# 14           4.123555            1       True          6
# 15           8.680067            1       True          8
# 16           2.643128            2       True         12
# 17           2.707051            1       True          3
# 18           2.730585            2       True         11
# 19           3.852532            1       True          1
# 20           2.237871            2       True         10
# 21          16.980584            1       True          7
# 22           5.633615            2       True         13
# 23           9.359899            1       True          4
# 24           5.470411            3       True         22
# 25           2.763918            3       True         20
# 26           3.852780            1       True          2

# %%
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score, average_precision_score
import pandas as pd

y_true = test_data['target'].values
y_pred = full_predictor.predict(test_data)  
y_proba = full_predictor.predict_proba(test_data)  

# ROC-AUC (complementa PR-AUC)
if isinstance(y_proba, pd.DataFrame):
    y_scores = y_proba[1].values if 1 in y_proba.columns else y_proba.iloc[:, -1].values
else:
    y_scores = y_proba[:, 1]

print(f"ROC-AUC: {roc_auc_score(y_true, y_scores):.4f}")
print(f"PR-AUC:  {average_precision_score(y_true, y_scores):.4f}")

# Matriz de confusión
cm = confusion_matrix(y_true, y_pred)
print("\nConfusion Matrix:")
print(f"TN: {cm[0,0]:4d}  FP: {cm[0,1]:4d}")
print(f"FN: {cm[1,0]:4d}  TP: {cm[1,1]:4d}")

# Reporte detallado
print("\n" + classification_report(y_true, y_pred, 
      target_names=['Not Confirmed', 'Confirmed']))
# Out:
# ROC-AUC: 0.9853
# PR-AUC:  0.9653
#
# Confusion Matrix:
# TN: 1980  FP:   66
# FN:   91  TP:  733
#
#                precision    recall  f1-score   support
#
# Not Confirmed       0.96      0.97      0.96      2046
#     Confirmed       0.92      0.89      0.90       824
#
#      accuracy                           0.95      2870
#     macro avg       0.94      0.93      0.93      2870
#  weighted avg       0.94      0.95      0.95      2870

# %%
# Identificar casos donde el modelo falla
test_with_preds = test.copy()
test_with_preds['pred'] = y_pred
test_with_preds['pred_proba'] = y_scores
test_with_preds['error'] = test_with_preds['target'] != test_with_preds['pred']

# Falsos Positivos
fp = test_with_preds[(test_with_preds['target']==0) & (test_with_preds['pred']==1)]
print(f"\nFalsos Positivos: {len(fp)}")
if len(fp) > 0:
    print(fp[['kepid', 'koi_period', 'koi_depth', 'pred_proba']].head())

# Falsos Negativos
fn = test_with_preds[(test_with_preds['target']==1) & (test_with_preds['pred']==0)]
print(f"\nFalsos Negativos: {len(fn)}")
if len(fn) > 0:
    print(fn[['kepid', 'koi_period', 'koi_depth', 'pred_proba']].head())
# Out:
# Falsos Positivos: 66
#          kepid  koi_period  koi_depth  pred_proba
# 1794   7449554    2.420883      223.3    0.886889
# 1189   9850893    8.480398      259.7    0.662288
# 2366  12602314    1.407020      181.9    0.821933
# 5143   5621333   27.096515      208.4    0.934453
# 2288  10336951   38.229204      605.8    0.945061
#
# Falsos Negativos: 91
#          kepid  koi_period  koi_depth  pred_proba
# 5873   4947556   13.026796      356.6    0.198349
# 778    7532973    2.144632    19837.0    0.001846
# 4927   6705026    9.508487       97.9    0.357797
# 6810   8037038    4.095139      181.7    0.409216
# 953   11517719    2.495780    25070.0    0.029159

# %%
# Ver qué features usa el modelo
fi = full_predictor.feature_importance(test_data, silent=True)  # ← Cambio aquí
print("\nTop 15 Features:")
print(fi.head(15))
# Out:
# Top 15 Features:
#                   importance    stddev   p_value  n  p99_high   p99_low
# koi_model_snr       0.038252  0.002516  0.000002  5  0.043434  0.033071
# koi_count           0.004963  0.000549  0.000018  5  0.006093  0.003833
# koi_prad            0.003807  0.001153  0.000895  5  0.006180  0.001434
# duration_anomaly    0.003277  0.000706  0.000244  5  0.004732  0.001822
# koi_dicco_mdec      0.002619  0.000371  0.000047  5  0.003382  0.001856
# koi_dicco_mra       0.002579  0.000451  0.000108  5  0.003509  0.001650
# koi_fwm_srao        0.001197  0.000103  0.000007  5  0.001409  0.000984
# koi_smet            0.001084  0.000149  0.000041  5  0.001391  0.000778
# koi_dikco_mra       0.001084  0.000306  0.000684  5  0.001713  0.000455
# koi_dikco_mdec      0.000960  0.000255  0.000548  5  0.001486  0.000434
# transit_morgan      0.000917  0.000433  0.004559  5  0.001809  0.000024
# transit_ratio       0.000740  0.000340  0.004109  5  0.001440  0.000040
# koi_impact          0.000667  0.000269  0.002574  5  0.001220  0.000114
# log_prad            0.000644  0.000458  0.017360  5  0.001588 -0.000299
# koi_fittype         0.000635  0.000121  0.000152  5  0.000884  0.000385

# %%
print(full_predictor.path)
# Out:
# /home/jsr-mario/Documents/otros/cursos/NASA/Back/AutogluonModels/ag-20251005_205401
# *** SIGTERM received at time=1759697951 on cpu 9 ***
# PC: @     0x7f3481ddef26  (unknown)  epoll_wait
#     @     0x7f3481d12050  (unknown)  (unknown)
# [2025-10-05 14:59:11,299 E 12347 12347] logging.cc:497: *** SIGTERM received at time=1759697951 on cpu 9 ***
# [2025-10-05 14:59:11,299 E 12347 12347] logging.cc:497: PC: @     0x7f3481ddef26  (unknown)  epoll_wait
# [2025-10-05 14:59:11,299 E 12347 12347] logging.cc:497:     @     0x7f3481d12050  (unknown)  (unknown)
